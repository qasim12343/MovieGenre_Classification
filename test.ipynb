# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import re
import joblib
import copy
stop_words = set(stopwords.words('english'))
lemmatizer = nltk.WordNetLemmatizer()

# بارگذاری داده‌ها
data = pd.read_csv('train.txt', delimiter=' ::: ', engine='python')
test_data = pd.read_csv('test.txt', delimiter=' ::: ', engine='python')

# %%
d = test_data
# Preprocessing function
def preprocess_text(text):
  
  text = text.lower()
  text = re.sub(r'[^\w\s]', '', text)
  tokens = word_tokenize(text)

  # Optionally experiment with stemming instead (e.g., PorterStemmer)
  filtered_tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
  return ' '.join(filtered_tokens)


data['description'] = data['description'].apply(preprocess_text)

# %%
# from imblearn.under_sampling import RandomUnderSampler
# from imblearn.over_sampling import RandomOverSampler
# X_train = data['description']
# y_train = data['genre']

# X_train = X_train.values.reshape(-1, 1)

# ros = RandomOverSampler(random_state=42)
# X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

# resampled_train_data = pd.DataFrame({
#     'description': X_resampled.flatten(),
#     'genre': y_resampled
# })

# des = []
# genre = []
# for i in range(len(X_resampled)):
#     des.append(X_resampled[i][0])
#     genre.append(y_resampled[i][0])

# n = pd.DataFrame({'description':des, 'genre':y_resampled})
# data = n

# %%
data = pd.concat([d,data], ignore_index = True)
# تبدیل متون به بردارهای ویژگی با استفاده از TF-IDF
vectorizer = TfidfVectorizer(stop_words='english', max_features=10000)
X = vectorizer.fit_transform(data['description'])
y = data['genre']

# تقسیم داده‌ها به مجموعه‌های آموزشی و ارزیابی
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)


smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# آموزش مدل Naive Bayes
model = MultinomialNB()
model.fit(X_train_resampled, y_train_resampled)

# ارزیابی مدل
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))

# ذخیره مدل و بردار ساز برای استفاده در آینده
joblib.dump(model, 'knn_model.pkl')
joblib.dump(vectorizer, 'tfidf_vectorizer.pkl')
# Out:
#               precision    recall  f1-score   support
#
#       action       0.30      0.48      0.37       489
#    adventure       0.27      0.29      0.28       312
#    animation       0.19      0.24      0.21       186
#    biography       0.03      0.08      0.05        98
#       comedy       0.56      0.51      0.53      3011
#        crime       0.16      0.21      0.18       217
#  documentary       0.75      0.64      0.69      5276
#        drama       0.65      0.49      0.56      5415
#       family       0.18      0.21      0.19       307
#      fantasy       0.20      0.20      0.20       135
#      history       0.09      0.15      0.12       109
#       horror       0.55      0.67      0.60       905
#        music       0.34      0.73      0.46       296
#      musical       0.13      0.19      0.16        94
#      mystery       0.10      0.10      0.10       135
#   reality-tv       0.29      0.47      0.36       342
#      romance       0.11      0.31      0.17       268
#       sci-fi       0.32      0.48      0.39       264
#        short       0.42      0.33      0.37      2044
#        sport       0.41      0.73      0.52       183
#    talk-show       0.29      0.45      0.35       166
#     thriller       0.22      0.35      0.27       593
#      western       0.67      0.90      0.77       402
#
#     accuracy                           0.51     21247
#    macro avg       0.31      0.40      0.34     21247
# weighted avg       0.55      0.51      0.52     21247
# ['tfidf_vectorizer.pkl']

# %%
# بارگذاری مدل و بردار ساز
model = joblib.load('knn_model.pkl')
vectorizer = joblib.load('tfidf_vectorizer.pkl')

# %%
def predict_genre(description):
    # تبدیل توضیح جدید به بردار ویژگی
    X_new = vectorizer.transform([description])
    
    # پیش‌بینی ژانر
    predicted_genre = model.predict(X_new)
    
    return predicted_genre[0]

n = 0
for i in range(2000):
    new_description = test_data['description'][i]
    predicted_genre = predict_genre(new_description)
    print(f'The predicted genre is: {predicted_genre}',test_data['genre'][i])
    if predicted_genre == test_data['genre'][i]:
        n+=1
    i+=1
print(n)
# Out:
# The predicted genre is: drama comedy
# The predicted genre is: adventure short
# The predicted genre is: drama drama
# The predicted genre is: crime crime
# The predicted genre is: short short
# The predicted genre is: western western
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: thriller drama
# The predicted genre is: thriller thriller
# The predicted genre is: drama drama
# The predicted genre is: sci-fi adventure
# The predicted genre is: drama comedy
# The predicted genre is: thriller thriller
# The predicted genre is: drama comedy
# The predicted genre is: documentary drama
# The predicted genre is: documentary drama
# The predicted genre is: animation animation
# The predicted genre is: documentary adventure
# The predicted genre is: sci-fi comedy
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: action action
# The predicted genre is: romance romance
# The predicted genre is: thriller thriller
# The predicted genre is: documentary documentary
# The predicted genre is: action action
# The predicted genre is: adventure adventure
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: family family
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: talk-show comedy
# The predicted genre is: drama mystery
# The predicted genre is: action action
# The predicted genre is: horror short
# The predicted genre is: documentary drama
# The predicted genre is: crime crime
# The predicted genre is: music short
# The predicted genre is: romance drama
# The predicted genre is: animation short
# The predicted genre is: talk-show documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: short documentary
# The predicted genre is: animation animation
# The predicted genre is: documentary documentary
# The predicted genre is: thriller drama
# The predicted genre is: documentary documentary
# The predicted genre is: short short
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: adventure documentary
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: horror horror
# The predicted genre is: drama drama
# The predicted genre is: romance short
# The predicted genre is: documentary drama
# The predicted genre is: thriller biography
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: animation comedy
# The predicted genre is: comedy comedy
# The predicted genre is: documentary comedy
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: crime crime
# The predicted genre is: crime crime
# The predicted genre is: documentary drama
# The predicted genre is: horror horror
# The predicted genre is: comedy short
# The predicted genre is: musical musical
# The predicted genre is: documentary documentary
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: fantasy fantasy
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: talk-show reality-tv
# The predicted genre is: family family
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: documentary documentary
# The predicted genre is: documentary short
# The predicted genre is: horror horror
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: short short
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: romance drama
# The predicted genre is: horror comedy
# The predicted genre is: documentary drama
# The predicted genre is: documentary documentary
# The predicted genre is: romance romance
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: documentary talk-show
# The predicted genre is: short short
# The predicted genre is: western western
# The predicted genre is: short short
# The predicted genre is: short documentary
# The predicted genre is: horror horror
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: documentary short
# The predicted genre is: drama drama
# The predicted genre is: mystery mystery
# The predicted genre is: sci-fi documentary
# The predicted genre is: talk-show documentary
# The predicted genre is: documentary documentary
# The predicted genre is: horror horror
# The predicted genre is: thriller thriller
# The predicted genre is: drama drama
# The predicted genre is: crime crime
# The predicted genre is: documentary documentary
# The predicted genre is: horror horror
# The predicted genre is: crime crime
# The predicted genre is: talk-show comedy
# The predicted genre is: comedy comedy
# The predicted genre is: action action
# The predicted genre is: documentary documentary
# The predicted genre is: action drama
# The predicted genre is: drama drama
# The predicted genre is: sci-fi documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: romance musical
# The predicted genre is: sport sport
# The predicted genre is: comedy drama
# The predicted genre is: action drama
# The predicted genre is: romance romance
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: adventure adventure
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: comedy drama
# The predicted genre is: drama comedy
# The predicted genre is: horror thriller
# The predicted genre is: horror horror
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: sport sport
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: music music
# The predicted genre is: sport sport
# The predicted genre is: documentary drama
# The predicted genre is: short short
# The predicted genre is: thriller drama
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: documentary comedy
# The predicted genre is: documentary documentary
# The predicted genre is: short comedy
# The predicted genre is: documentary drama
# The predicted genre is: sci-fi documentary
# The predicted genre is: drama drama
# The predicted genre is: horror horror
# The predicted genre is: music documentary
# The predicted genre is: comedy comedy
# The predicted genre is: music music
# The predicted genre is: comedy short
# The predicted genre is: romance documentary
# The predicted genre is: crime crime
# The predicted genre is: drama drama
# The predicted genre is: sport sport
# The predicted genre is: action action
# The predicted genre is: drama documentary
# The predicted genre is: drama drama
# The predicted genre is: history drama
# The predicted genre is: horror drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary short
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: music short
# The predicted genre is: thriller drama
# The predicted genre is: action action
# The predicted genre is: documentary documentary
# The predicted genre is: short short
# The predicted genre is: horror horror
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: animation animation
# The predicted genre is: short short
# The predicted genre is: western western
# The predicted genre is: thriller thriller
# The predicted genre is: documentary documentary
# The predicted genre is: mystery mystery
# The predicted genre is: short short
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: drama drama
# The predicted genre is: adventure adventure
# The predicted genre is: comedy drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: crime crime
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: action action
# The predicted genre is: drama drama
# The predicted genre is: action action
# The predicted genre is: music documentary
# The predicted genre is: sport sport
# The predicted genre is: sport sport
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: talk-show talk-show
# The predicted genre is: fantasy fantasy
# The predicted genre is: family drama
# The predicted genre is: horror horror
# The predicted genre is: comedy comedy
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: music short
# The predicted genre is: documentary short
# The predicted genre is: drama drama
# The predicted genre is: animation documentary
# The predicted genre is: sci-fi documentary
# The predicted genre is: family family
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: thriller drama
# The predicted genre is: comedy comedy
# The predicted genre is: thriller thriller
# The predicted genre is: drama drama
# The predicted genre is: documentary short
# The predicted genre is: drama action
# The predicted genre is: comedy talk-show
# The predicted genre is: drama drama
# The predicted genre is: documentary drama
# The predicted genre is: romance romance
# The predicted genre is: drama drama
# The predicted genre is: animation short
# The predicted genre is: documentary documentary
# The predicted genre is: drama comedy
# The predicted genre is: talk-show documentary
# The predicted genre is: documentary drama
# The predicted genre is: short documentary
# The predicted genre is: sci-fi drama
# The predicted genre is: thriller drama
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: documentary comedy
# The predicted genre is: documentary documentary
# The predicted genre is: romance short
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: documentary musical
# The predicted genre is: thriller drama
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: music family
# The predicted genre is: music music
# The predicted genre is: documentary documentary
# The predicted genre is: romance romance
# The predicted genre is: family drama
# The predicted genre is: documentary documentary
# The predicted genre is: history history
# The predicted genre is: comedy documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: music music
# The predicted genre is: thriller drama
# The predicted genre is: horror horror
# The predicted genre is: short documentary
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: documentary documentary
# The predicted genre is: romance romance
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: sport documentary
# The predicted genre is: crime drama
# The predicted genre is: documentary short
# The predicted genre is: documentary documentary
# The predicted genre is: action drama
# The predicted genre is: action comedy
# The predicted genre is: documentary short
# The predicted genre is: thriller thriller
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: horror horror
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: documentary documentary
# The predicted genre is: history history
# The predicted genre is: mystery drama
# The predicted genre is: horror fantasy
# The predicted genre is: documentary documentary
# The predicted genre is: western western
# The predicted genre is: drama drama
# The predicted genre is: reality-tv documentary
# The predicted genre is: western western
# The predicted genre is: drama drama
# The predicted genre is: talk-show talk-show
# The predicted genre is: music drama
# The predicted genre is: comedy comedy
# The predicted genre is: action comedy
# The predicted genre is: drama documentary
# The predicted genre is: short short
# The predicted genre is: reality-tv horror
# The predicted genre is: action action
# The predicted genre is: comedy comedy
# The predicted genre is: horror horror
# The predicted genre is: horror horror
# The predicted genre is: comedy drama
# The predicted genre is: documentary documentary
# The predicted genre is: short short
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: thriller action
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: family family
# The predicted genre is: talk-show talk-show
# The predicted genre is: adventure adventure
# The predicted genre is: documentary documentary
# The predicted genre is: short short
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: adventure adventure
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary short
# The predicted genre is: thriller thriller
# The predicted genre is: short short
# The predicted genre is: music music
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: thriller drama
# The predicted genre is: romance romance
# The predicted genre is: comedy comedy
# The predicted genre is: romance drama
# The predicted genre is: short drama
# The predicted genre is: documentary documentary
# The predicted genre is: animation animation
# The predicted genre is: reality-tv documentary
# The predicted genre is: animation animation
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: family family
# The predicted genre is: drama comedy
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: action action
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: comedy documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary short
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary short
# The predicted genre is: comedy short
# The predicted genre is: drama drama
# The predicted genre is: documentary drama
# The predicted genre is: comedy documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: horror horror
# The predicted genre is: music music
# The predicted genre is: talk-show comedy
# The predicted genre is: action drama
# The predicted genre is: horror horror
# The predicted genre is: drama drama
# The predicted genre is: short documentary
# The predicted genre is: animation action
# The predicted genre is: adventure comedy
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: animation animation
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: documentary documentary
# The predicted genre is: drama comedy
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: comedy drama
# The predicted genre is: comedy comedy
# The predicted genre is: drama documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: short comedy
# The predicted genre is: short drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: western western
# The predicted genre is: drama drama
# The predicted genre is: action music
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: family comedy
# The predicted genre is: comedy drama
# The predicted genre is: action action
# The predicted genre is: short comedy
# The predicted genre is: talk-show comedy
# The predicted genre is: short drama
# The predicted genre is: drama drama
# The predicted genre is: animation animation
# The predicted genre is: action action
# The predicted genre is: musical musical
# The predicted genre is: musical musical
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: crime comedy
# The predicted genre is: animation animation
# The predicted genre is: thriller short
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: drama comedy
# The predicted genre is: horror comedy
# The predicted genre is: music documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: short drama
# The predicted genre is: drama documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: fantasy drama
# The predicted genre is: comedy comedy
# The predicted genre is: western drama
# The predicted genre is: reality-tv documentary
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: action action
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: horror horror
# The predicted genre is: biography short
# The predicted genre is: romance drama
# The predicted genre is: sport documentary
# The predicted genre is: drama drama
# The predicted genre is: music documentary
# The predicted genre is: comedy comedy
# The predicted genre is: thriller comedy
# The predicted genre is: short drama
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: drama documentary
# The predicted genre is: documentary documentary
# The predicted genre is: crime drama
# The predicted genre is: documentary documentary
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: musical comedy
# The predicted genre is: short comedy
# The predicted genre is: drama drama
# The predicted genre is: horror horror
# The predicted genre is: drama documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: western western
# The predicted genre is: drama documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: comedy documentary
# The predicted genre is: comedy drama
# The predicted genre is: documentary documentary
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: adventure adventure
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: action western
# The predicted genre is: drama documentary
# The predicted genre is: comedy comedy
# The predicted genre is: drama documentary
# The predicted genre is: romance comedy
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: horror horror
# The predicted genre is: mystery mystery
# The predicted genre is: mystery mystery
# The predicted genre is: family comedy
# The predicted genre is: family drama
# The predicted genre is: drama drama
# The predicted genre is: horror documentary
# The predicted genre is: romance mystery
# The predicted genre is: musical musical
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: action drama
# The predicted genre is: short short
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: adventure adventure
# The predicted genre is: family family
# The predicted genre is: documentary documentary
# The predicted genre is: thriller comedy
# The predicted genre is: documentary drama
# The predicted genre is: short short
# The predicted genre is: music music
# The predicted genre is: documentary horror
# The predicted genre is: biography biography
# The predicted genre is: romance comedy
# The predicted genre is: music music
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: sci-fi horror
# The predicted genre is: animation animation
# The predicted genre is: fantasy fantasy
# The predicted genre is: documentary thriller
# The predicted genre is: mystery drama
# The predicted genre is: documentary drama
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: romance horror
# The predicted genre is: drama drama
# The predicted genre is: romance drama
# The predicted genre is: drama drama
# The predicted genre is: short drama
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: adventure adventure
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: music documentary
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: action drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: horror horror
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: animation comedy
# The predicted genre is: documentary drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: action action
# The predicted genre is: documentary documentary
# The predicted genre is: drama comedy
# The predicted genre is: action comedy
# The predicted genre is: short short
# The predicted genre is: comedy comedy
# The predicted genre is: action action
# The predicted genre is: horror horror
# The predicted genre is: drama drama
# The predicted genre is: family short
# The predicted genre is: action action
# The predicted genre is: comedy comedy
# The predicted genre is: romance comedy
# The predicted genre is: family short
# The predicted genre is: adventure adventure
# The predicted genre is: western drama
# The predicted genre is: romance drama
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: action action
# The predicted genre is: reality-tv documentary
# The predicted genre is: reality-tv documentary
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: documentary short
# The predicted genre is: romance romance
# The predicted genre is: action action
# The predicted genre is: drama documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: adventure adventure
# The predicted genre is: comedy comedy
# The predicted genre is: short documentary
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: sport documentary
# The predicted genre is: documentary documentary
# The predicted genre is: adventure adventure
# The predicted genre is: music documentary
# The predicted genre is: comedy comedy
# The predicted genre is: romance romance
# The predicted genre is: action action
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: short documentary
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: documentary documentary
# The predicted genre is: horror horror
# The predicted genre is: romance drama
# The predicted genre is: short short
# The predicted genre is: talk-show history
# The predicted genre is: thriller drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: talk-show documentary
# The predicted genre is: talk-show documentary
# The predicted genre is: thriller drama
# The predicted genre is: drama drama
# The predicted genre is: family family
# The predicted genre is: music music
# The predicted genre is: documentary documentary
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: documentary documentary
# The predicted genre is: fantasy drama
# The predicted genre is: drama drama
# The predicted genre is: animation comedy
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: documentary documentary
# The predicted genre is: fantasy fantasy
# The predicted genre is: drama drama
# The predicted genre is: western western
# The predicted genre is: musical musical
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: horror horror
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: western western
# The predicted genre is: horror short
# The predicted genre is: history history
# The predicted genre is: documentary comedy
# The predicted genre is: music documentary
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: action action
# The predicted genre is: drama drama
# The predicted genre is: adventure adventure
# The predicted genre is: drama comedy
# The predicted genre is: sci-fi documentary
# The predicted genre is: romance drama
# The predicted genre is: romance drama
# The predicted genre is: thriller thriller
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: romance romance
# The predicted genre is: drama short
# The predicted genre is: sport documentary
# The predicted genre is: drama documentary
# The predicted genre is: reality-tv comedy
# The predicted genre is: drama drama
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: mystery comedy
# The predicted genre is: thriller comedy
# The predicted genre is: drama documentary
# The predicted genre is: drama short
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: musical comedy
# The predicted genre is: adventure adventure
# The predicted genre is: comedy comedy
# The predicted genre is: action drama
# The predicted genre is: music music
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: short documentary
# The predicted genre is: drama drama
# The predicted genre is: sport sport
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: horror sci-fi
# The predicted genre is: talk-show talk-show
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: short documentary
# The predicted genre is: drama comedy
# The predicted genre is: thriller thriller
# The predicted genre is: comedy comedy
# The predicted genre is: music documentary
# The predicted genre is: comedy comedy
# The predicted genre is: horror horror
# The predicted genre is: thriller drama
# The predicted genre is: animation documentary
# The predicted genre is: documentary documentary
# The predicted genre is: talk-show documentary
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: fantasy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: documentary family
# The predicted genre is: short comedy
# The predicted genre is: sport sport
# The predicted genre is: short short
# The predicted genre is: comedy drama
# The predicted genre is: thriller mystery
# The predicted genre is: sport short
# The predicted genre is: drama drama
# The predicted genre is: horror horror
# The predicted genre is: drama drama
# The predicted genre is: documentary short
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: drama drama
# The predicted genre is: thriller drama
# The predicted genre is: documentary documentary
# The predicted genre is: sport sport
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: comedy comedy
# The predicted genre is: short drama
# The predicted genre is: documentary documentary
# The predicted genre is: family family
# The predicted genre is: fantasy fantasy
# The predicted genre is: drama drama
# The predicted genre is: documentary short
# The predicted genre is: crime short
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: thriller thriller
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: music music
# The predicted genre is: drama horror
# The predicted genre is: family drama
# The predicted genre is: action action
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: documentary documentary
# The predicted genre is: action action
# The predicted genre is: documentary documentary
# The predicted genre is: family family
# The predicted genre is: documentary documentary
# The predicted genre is: documentary sci-fi
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: short short
# The predicted genre is: drama short
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: crime drama
# The predicted genre is: drama drama
# The predicted genre is: biography biography
# The predicted genre is: short drama
# The predicted genre is: documentary documentary
# The predicted genre is: action thriller
# The predicted genre is: talk-show documentary
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: reality-tv documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: drama documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: biography documentary
# The predicted genre is: drama drama
# The predicted genre is: short comedy
# The predicted genre is: short short
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: mystery mystery
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: romance drama
# The predicted genre is: drama romance
# The predicted genre is: drama drama
# The predicted genre is: western western
# The predicted genre is: documentary drama
# The predicted genre is: drama drama
# The predicted genre is: thriller thriller
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: comedy short
# The predicted genre is: family drama
# The predicted genre is: drama drama
# The predicted genre is: music music
# The predicted genre is: thriller horror
# The predicted genre is: short short
# The predicted genre is: drama comedy
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: action action
# The predicted genre is: crime drama
# The predicted genre is: music music
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: romance drama
# The predicted genre is: short documentary
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: thriller drama
# The predicted genre is: thriller documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: reality-tv short
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: adventure documentary
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: history history
# The predicted genre is: adventure adventure
# The predicted genre is: drama thriller
# The predicted genre is: drama drama
# The predicted genre is: horror horror
# The predicted genre is: horror horror
# The predicted genre is: horror documentary
# The predicted genre is: action documentary
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: music documentary
# The predicted genre is: drama short
# The predicted genre is: short short
# The predicted genre is: romance comedy
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: sci-fi animation
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: family comedy
# The predicted genre is: horror horror
# The predicted genre is: comedy drama
# The predicted genre is: romance romance
# The predicted genre is: short action
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: horror horror
# The predicted genre is: reality-tv short
# The predicted genre is: comedy drama
# The predicted genre is: adventure adventure
# The predicted genre is: comedy drama
# The predicted genre is: short documentary
# The predicted genre is: drama drama
# The predicted genre is: drama horror
# The predicted genre is: comedy drama
# The predicted genre is: musical musical
# The predicted genre is: documentary documentary
# The predicted genre is: horror romance
# The predicted genre is: family family
# The predicted genre is: documentary drama
# The predicted genre is: drama comedy
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: thriller drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: music music
# The predicted genre is: action comedy
# The predicted genre is: talk-show talk-show
# The predicted genre is: comedy comedy
# The predicted genre is: horror comedy
# The predicted genre is: music music
# The predicted genre is: thriller thriller
# The predicted genre is: short western
# The predicted genre is: western western
# The predicted genre is: documentary documentary
# The predicted genre is: crime comedy
# The predicted genre is: music documentary
# The predicted genre is: comedy comedy
# The predicted genre is: short documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: comedy short
# The predicted genre is: drama drama
# The predicted genre is: horror horror
# The predicted genre is: comedy comedy
# The predicted genre is: action action
# The predicted genre is: adventure short
# The predicted genre is: documentary drama
# The predicted genre is: drama comedy
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: fantasy fantasy
# The predicted genre is: drama drama
# The predicted genre is: music comedy
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: western drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary short
# The predicted genre is: drama drama
# The predicted genre is: drama comedy
# The predicted genre is: sci-fi short
# The predicted genre is: drama comedy
# The predicted genre is: documentary documentary
# The predicted genre is: action action
# The predicted genre is: thriller documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: horror horror
# The predicted genre is: documentary drama
# The predicted genre is: drama drama
# The predicted genre is: animation drama
# The predicted genre is: drama thriller
# The predicted genre is: horror drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: musical musical
# The predicted genre is: drama comedy
# The predicted genre is: music music
# The predicted genre is: comedy comedy
# The predicted genre is: action drama
# The predicted genre is: drama drama
# The predicted genre is: short documentary
# The predicted genre is: music short
# The predicted genre is: sci-fi short
# The predicted genre is: talk-show talk-show
# The predicted genre is: drama drama
# The predicted genre is: reality-tv documentary
# The predicted genre is: drama drama
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: documentary documentary
# The predicted genre is: short documentary
# The predicted genre is: comedy comedy
# The predicted genre is: action action
# The predicted genre is: history history
# The predicted genre is: fantasy fantasy
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: documentary documentary
# The predicted genre is: action action
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: biography biography
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: action action
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: history drama
# The predicted genre is: short short
# The predicted genre is: western western
# The predicted genre is: documentary documentary
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: documentary drama
# The predicted genre is: family comedy
# The predicted genre is: documentary documentary
# The predicted genre is: documentary drama
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: music comedy
# The predicted genre is: crime crime
# The predicted genre is: comedy short
# The predicted genre is: short mystery
# The predicted genre is: documentary drama
# The predicted genre is: short short
# The predicted genre is: action comedy
# The predicted genre is: comedy short
# The predicted genre is: thriller drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama documentary
# The predicted genre is: biography drama
# The predicted genre is: drama drama
# The predicted genre is: comedy horror
# The predicted genre is: documentary documentary
# The predicted genre is: documentary drama
# The predicted genre is: music documentary
# The predicted genre is: comedy comedy
# The predicted genre is: western western
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: romance romance
# The predicted genre is: short short
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: drama romance
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: comedy comedy
# The predicted genre is: talk-show talk-show
# The predicted genre is: comedy comedy
# The predicted genre is: short short
# The predicted genre is: animation animation
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: romance comedy
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: thriller thriller
# The predicted genre is: documentary short
# The predicted genre is: drama drama
# The predicted genre is: horror drama
# The predicted genre is: thriller thriller
# The predicted genre is: horror horror
# The predicted genre is: documentary short
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama family
# The predicted genre is: romance comedy
# The predicted genre is: short documentary
# The predicted genre is: crime drama
# The predicted genre is: comedy comedy
# The predicted genre is: documentary short
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: musical documentary
# The predicted genre is: animation animation
# The predicted genre is: documentary documentary
# The predicted genre is: action action
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: thriller drama
# The predicted genre is: short short
# The predicted genre is: comedy comedy
# The predicted genre is: documentary short
# The predicted genre is: short short
# The predicted genre is: short short
# The predicted genre is: comedy short
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: sci-fi horror
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: thriller thriller
# The predicted genre is: documentary documentary
# The predicted genre is: mystery mystery
# The predicted genre is: drama drama
# The predicted genre is: action action
# The predicted genre is: drama drama
# The predicted genre is: music documentary
# The predicted genre is: drama drama
# The predicted genre is: comedy drama
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: drama drama
# The predicted genre is: documentary short
# The predicted genre is: drama short
# The predicted genre is: adventure adventure
# The predicted genre is: documentary reality-tv
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: drama drama
# The predicted genre is: crime crime
# The predicted genre is: drama short
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: family drama
# The predicted genre is: drama drama
# The predicted genre is: romance documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: comedy documentary
# The predicted genre is: documentary documentary
# The predicted genre is: thriller drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary action
# The predicted genre is: action action
# The predicted genre is: documentary documentary
# The predicted genre is: western drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: action drama
# The predicted genre is: comedy comedy
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: drama drama
# The predicted genre is: thriller drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: horror horror
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: documentary documentary
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: short drama
# The predicted genre is: adventure adventure
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: romance short
# The predicted genre is: mystery drama
# The predicted genre is: short short
# ...
# The predicted genre is: short comedy
# The predicted genre is: family family
# The predicted genre is: family comedy
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: talk-show talk-show
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama romance
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: music short
# The predicted genre is: drama drama
# The predicted genre is: musical musical
# The predicted genre is: comedy comedy
# The predicted genre is: drama short
# The predicted genre is: documentary documentary
# The predicted genre is: horror animation
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: short comedy
# The predicted genre is: animation animation
# The predicted genre is: documentary short
# The predicted genre is: short documentary
# The predicted genre is: romance drama
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: comedy drama
# The predicted genre is: drama comedy
# The predicted genre is: reality-tv documentary
# The predicted genre is: sci-fi family
# The predicted genre is: thriller short
# The predicted genre is: thriller action
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: romance drama
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: animation animation
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary drama
# The predicted genre is: drama comedy
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: talk-show talk-show
# The predicted genre is: romance romance
# The predicted genre is: sport documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: short mystery
# The predicted genre is: sport short
# The predicted genre is: music musical
# The predicted genre is: drama short
# The predicted genre is: action action
# The predicted genre is: comedy comedy
# The predicted genre is: action documentary
# The predicted genre is: drama drama
# The predicted genre is: talk-show documentary
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: sport sport
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: western western
# The predicted genre is: horror horror
# The predicted genre is: adventure adventure
# The predicted genre is: thriller thriller
# The predicted genre is: comedy comedy
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: drama comedy
# The predicted genre is: musical drama
# The predicted genre is: documentary documentary
# The predicted genre is: short documentary
# The predicted genre is: short documentary
# The predicted genre is: horror horror
# The predicted genre is: reality-tv short
# The predicted genre is: thriller drama
# The predicted genre is: romance romance
# The predicted genre is: drama short
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: comedy drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: romance drama
# The predicted genre is: music documentary
# The predicted genre is: documentary short
# The predicted genre is: horror documentary
# The predicted genre is: thriller drama
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: short short
# The predicted genre is: music music
# The predicted genre is: comedy comedy
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary adventure
# The predicted genre is: documentary documentary
# The predicted genre is: music comedy
# The predicted genre is: documentary documentary
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: documentary animation
# The predicted genre is: drama drama
# The predicted genre is: animation drama
# The predicted genre is: romance drama
# The predicted genre is: short drama
# The predicted genre is: adventure adventure
# The predicted genre is: romance romance
# The predicted genre is: drama short
# The predicted genre is: short documentary
# The predicted genre is: documentary documentary
# The predicted genre is: action history
# The predicted genre is: documentary documentary
# The predicted genre is: thriller drama
# The predicted genre is: action action
# The predicted genre is: horror horror
# The predicted genre is: action action
# The predicted genre is: drama drama
# The predicted genre is: thriller drama
# The predicted genre is: comedy comedy
# The predicted genre is: documentary drama
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: horror short
# The predicted genre is: reality-tv comedy
# The predicted genre is: comedy comedy
# The predicted genre is: music music
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: comedy short
# The predicted genre is: talk-show talk-show
# The predicted genre is: documentary reality-tv
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: western western
# The predicted genre is: drama drama
# The predicted genre is: documentary drama
# The predicted genre is: western action
# The predicted genre is: comedy comedy
# The predicted genre is: action action
# The predicted genre is: comedy short
# The predicted genre is: horror drama
# The predicted genre is: action action
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: sci-fi documentary
# The predicted genre is: history history
# The predicted genre is: drama drama
# The predicted genre is: thriller thriller
# The predicted genre is: fantasy fantasy
# The predicted genre is: romance comedy
# The predicted genre is: reality-tv comedy
# The predicted genre is: western western
# The predicted genre is: comedy comedy
# The predicted genre is: western western
# The predicted genre is: documentary documentary
# The predicted genre is: short short
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: short comedy
# The predicted genre is: sci-fi drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama thriller
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: horror horror
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: documentary short
# The predicted genre is: documentary documentary
# The predicted genre is: family fantasy
# The predicted genre is: family family
# The predicted genre is: western western
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: documentary documentary
# The predicted genre is: drama short
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: thriller musical
# The predicted genre is: sport talk-show
# The predicted genre is: drama drama
# The predicted genre is: adventure adventure
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: thriller drama
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: mystery mystery
# The predicted genre is: action documentary
# The predicted genre is: history history
# The predicted genre is: comedy drama
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: family family
# The predicted genre is: adventure adventure
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: short documentary
# The predicted genre is: thriller action
# The predicted genre is: comedy drama
# The predicted genre is: horror western
# The predicted genre is: reality-tv reality-tv
# The predicted genre is: short reality-tv
# The predicted genre is: horror horror
# The predicted genre is: horror comedy
# The predicted genre is: comedy comedy
# The predicted genre is: thriller thriller
# The predicted genre is: comedy documentary
# The predicted genre is: horror short
# The predicted genre is: thriller drama
# The predicted genre is: animation comedy
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: thriller sci-fi
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: comedy comedy
# The predicted genre is: comedy comedy
# The predicted genre is: sport sport
# The predicted genre is: short short
# The predicted genre is: comedy comedy
# The predicted genre is: musical musical
# The predicted genre is: romance drama
# The predicted genre is: crime drama
# The predicted genre is: crime crime
# The predicted genre is: short short
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: romance drama
# The predicted genre is: documentary documentary
# The predicted genre is: thriller drama
# The predicted genre is: documentary documentary
# The predicted genre is: adventure adventure
# The predicted genre is: music documentary
# The predicted genre is: drama documentary
# The predicted genre is: reality-tv documentary
# The predicted genre is: drama drama
# The predicted genre is: horror horror
# The predicted genre is: romance action
# The predicted genre is: western western
# The predicted genre is: adventure adventure
# The predicted genre is: drama drama
# The predicted genre is: talk-show talk-show
# The predicted genre is: sport sport
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: drama adventure
# The predicted genre is: talk-show documentary
# The predicted genre is: thriller short
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: history documentary
# The predicted genre is: thriller thriller
# The predicted genre is: adventure documentary
# The predicted genre is: comedy comedy
# The predicted genre is: romance drama
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: drama documentary
# The predicted genre is: action romance
# The predicted genre is: music music
# The predicted genre is: music documentary
# The predicted genre is: drama drama
# The predicted genre is: comedy comedy
# The predicted genre is: western western
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: family family
# The predicted genre is: comedy comedy
# The predicted genre is: drama drama
# The predicted genre is: reality-tv documentary
# The predicted genre is: drama short
# The predicted genre is: documentary documentary
# The predicted genre is: musical drama
# The predicted genre is: romance romance
# The predicted genre is: crime drama
# The predicted genre is: comedy drama
# The predicted genre is: drama comedy
# The predicted genre is: comedy comedy
# The predicted genre is: short drama
# The predicted genre is: documentary documentary
# The predicted genre is: short documentary
# The predicted genre is: music biography
# The predicted genre is: drama drama
# The predicted genre is: thriller short
# The predicted genre is: romance drama
# The predicted genre is: drama documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: comedy drama
# The predicted genre is: documentary drama
# The predicted genre is: horror horror
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: short short
# The predicted genre is: reality-tv drama
# The predicted genre is: drama mystery
# The predicted genre is: western drama
# The predicted genre is: documentary documentary
# The predicted genre is: horror horror
# The predicted genre is: short action
# The predicted genre is: drama drama
# The predicted genre is: adventure adventure
# The predicted genre is: short short
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: romance comedy
# The predicted genre is: short short
# The predicted genre is: western western
# The predicted genre is: documentary short
# The predicted genre is: music musical
# The predicted genre is: thriller short
# The predicted genre is: adventure comedy
# The predicted genre is: action comedy
# The predicted genre is: music music
# The predicted genre is: comedy comedy
# The predicted genre is: thriller thriller
# The predicted genre is: documentary documentary
# The predicted genre is: thriller thriller
# The predicted genre is: documentary documentary
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# The predicted genre is: comedy documentary
# The predicted genre is: music music
# The predicted genre is: sci-fi sci-fi
# The predicted genre is: sport sport
# The predicted genre is: short short
# The predicted genre is: drama drama
# The predicted genre is: drama drama
# The predicted genre is: short short
# The predicted genre is: comedy comedy
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: action action
# The predicted genre is: comedy comedy
# The predicted genre is: talk-show talk-show
# The predicted genre is: short short
# The predicted genre is: comedy comedy
# The predicted genre is: short short
# The predicted genre is: documentary documentary
# The predicted genre is: documentary documentary
# The predicted genre is: drama adventure
# The predicted genre is: sci-fi drama
# The predicted genre is: documentary documentary
# The predicted genre is: family family
# The predicted genre is: drama drama
# The predicted genre is: crime crime
# The predicted genre is: thriller comedy
# The predicted genre is: comedy crime
# The predicted genre is: documentary short
# The predicted genre is: documentary documentary
# The predicted genre is: thriller comedy
# The predicted genre is: drama drama
# The predicted genre is: crime drama
# The predicted genre is: drama drama
# The predicted genre is: documentary documentary
# 1361

# %%
def predict_and_report(csv_file):
   
    model = joblib.load('knn_model.pkl')
    vectorizer = joblib.load('tfidf_vectorizer.pkl')

    new_data = pd.read_csv(csv_file, delimiter= ' ::: ',engine='python')
    new_data['description'] = new_data['description'].apply(preprocess_text)


    X_new = vectorizer.transform(new_data['description'])
    y_true = new_data['genre']

    
    y_pred = model.predict(X_new)

    
    print(classification_report(y_true, y_pred))

predict_and_report('test.txt')
# Out:
#               precision    recall  f1-score   support
#
#       action       0.46      0.63      0.53       197
#    adventure       0.47      0.52      0.49       116
#    animation       0.42      0.64      0.51        75
#    biography       0.16      0.40      0.23        40
#       comedy       0.65      0.59      0.62      1117
#        crime       0.33      0.53      0.41        76
#  documentary       0.79      0.65      0.71      1964
#        drama       0.73      0.52      0.61      2042
#       family       0.36      0.51      0.42       117
#      fantasy       0.44      0.54      0.49        48
#      history       0.29      0.61      0.39        36
#       horror       0.61      0.71      0.66       331
#        music       0.37      0.75      0.49       110
#      musical       0.36      0.59      0.44        41
#      mystery       0.26      0.38      0.31        48
#   reality-tv       0.40      0.71      0.51       133
#      romance       0.24      0.69      0.36       101
#       sci-fi       0.44      0.67      0.53        97
#        short       0.48      0.39      0.43       761
#        sport       0.47      0.88      0.61        65
#    talk-show       0.40      0.68      0.51        59
#     thriller       0.36      0.56      0.44       239
#      western       0.69      0.92      0.79       155
#
#     accuracy                           0.58      7968
#    macro avg       0.44      0.61      0.50      7968
# weighted avg       0.63      0.58      0.59      7968
